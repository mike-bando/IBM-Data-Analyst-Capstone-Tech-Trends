# %%
import pandas as pd

# %%
weather_data = pd.read_csv('/Users/michalbando/Downloads/Różne/IT/Practima.io - Kurs DA/drive-download-20250827T154251Z-1-001/Moduł 3 - Python/Weather_Data.csv')

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          100 non-null    object
#  1   Temperature  100 non-null    float64
#  2   Humidity     100 non-null    float64
#  3   Wind_Speed   100 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 3.3+ KB

# %%
weather_data
# Out:
#            Day  Temperature  Humidity  Wind_Speed
# 0   2023-01-01         28.8      55.4         8.7
# 1   2023-01-02         22.0      66.4        24.1
# 2   2023-01-03         24.9      31.2        18.7
# 3   2023-01-04         31.2      48.1         9.3
# 4   2023-01-05         29.3      69.6        23.9
# ..         ...          ...       ...         ...
# 95  2023-04-06         23.5      79.9        19.5
# 96  2023-04-07         20.1      67.7        10.4
# 97  2023-04-08         28.9      82.4         7.6
# 98  2023-04-09         20.6      46.4         6.1
# 99  2023-04-10         22.0      77.9        11.0
#
# [100 rows x 4 columns]

# %%
weather_data['Day'] = weather_data['Day'].sort_values(ascending=False)

# %%
weather_data.set_index('Day', inplace = True)

# %%
weather_data
# Out:
#             Temperature  Humidity  Wind_Speed
# Day
# 2023-01-01         28.8      55.4         8.7
# 2023-01-02         22.0      66.4        24.1
# 2023-01-03         24.9      31.2        18.7
# 2023-01-04         31.2      48.1         9.3
# 2023-01-05         29.3      69.6        23.9
# ...                 ...       ...         ...
# 2023-04-06         23.5      79.9        19.5
# 2023-04-07         20.1      67.7        10.4
# 2023-04-08         28.9      82.4         7.6
# 2023-04-09         20.6      46.4         6.1
# 2023-04-10         22.0      77.9        11.0
#
# [100 rows x 3 columns]

# %%
weather_data.tail()
# Out:
#             Temperature  Humidity  Wind_Speed
# Day
# 2023-04-06         23.5      79.9        19.5
# 2023-04-07         20.1      67.7        10.4
# 2023-04-08         28.9      82.4         7.6
# 2023-04-09         20.6      46.4         6.1
# 2023-04-10         22.0      77.9        11.0

# %%
library_data = pd.read_csv('/Users/michalbando/Downloads/Różne/IT/Practima.io - Kurs DA/drive-download-20250827T154251Z-1-001/Moduł 3 - Python/Library_Data.csv')

# %%
library_data.head()
# Out:
#    Checkout ID  Book ID   Title     Author  Year of Publication      Genre  \
# 0            1       39  Book 1   Author 9                 2022    Fiction
# 1            2       29  Book 2  Author 24                 1990    History
# 2            3       15  Book 3   Author 1                 2016    Science
# 3            4       43  Book 4  Author 12                 2002    Science
# 4            5        8  Book 5   Author 8                 1992  Biography
#
#    Page Count  Price  User ID     User Type  Late Return Fee  Renewals  \
# 0         205  29.31       44       Student               10         0
# 1         257  43.95       45       Student               10         0
# 2         246  13.51       32  Professional                0         1
# 3         244  65.64       45  Professional                0         2
# 4         219  40.29       47       Retired                5         3
#
#   Book Condition
# 0           Worn
# 1        Damaged
# 2            New
# ...

# %%
orders = pd.read_csv('/Users/michalbando/Downloads/Różne/IT/Practima.io - Kurs DA/drive-download-20250827T154251Z-1-001/Moduł 3 - Python/Orders.csv')

# %%
orders
# Out:
#    order_id  customer_id  order_date          product  quantity  price  \
# 0      5001          101  2024-02-01    Python Course         1  199.0
# 1      5002          102  2024-02-10  Tableau License         2   99.0
# 2      5003          103  2024-03-01     SQL Workshop         1  149.0
# 3      5004          104  2024-03-18     Pandas Ebook         3   29.0
# 4      5005          104  2024-03-25    Python Course         1  199.0
# 5      5006          105  2024-04-07     Data Viz Kit         5   39.0
# 6      5007          106  2024-04-20    Python Course         2  199.0
# 7      5008          107  2024-05-01     SQL Workshop         1  149.0
# 8      5009          108  2024-05-11     Pandas Ebook         2   29.0
# 9      5010          109  2024-06-01     Data Viz Kit         1   39.0
#
#   discount_code     status shipped_date
# 0     WELCOME10  completed   2024-02-02
# 1           NaN  completed   2024-02-12
# 2       SPRING5  completed   2024-03-02
# ...

# %%
orders = orders.rename(columns={'customer_id': 'User ID'})

# %%
orders
# Out:
#    order_id  User ID  order_date          product  quantity  price  \
# 0      5001      101  2024-02-01    Python Course         1  199.0
# 1      5002      102  2024-02-10  Tableau License         2   99.0
# 2      5003      103  2024-03-01     SQL Workshop         1  149.0
# 3      5004      104  2024-03-18     Pandas Ebook         3   29.0
# 4      5005      104  2024-03-25    Python Course         1  199.0
# 5      5006      105  2024-04-07     Data Viz Kit         5   39.0
# 6      5007      106  2024-04-20    Python Course         2  199.0
# 7      5008      107  2024-05-01     SQL Workshop         1  149.0
# 8      5009      108  2024-05-11     Pandas Ebook         2   29.0
# 9      5010      109  2024-06-01     Data Viz Kit         1   39.0
#
#   discount_code     status shipped_date
# 0     WELCOME10  completed   2024-02-02
# 1           NaN  completed   2024-02-12
# 2       SPRING5  completed   2024-03-02
# 3          NONE  completed   2024-03-19
# ...
